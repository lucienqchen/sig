# %%
from rolling_sharpe import *

# %%
start = dt.datetime(2016, 1, 1)
end = dt.datetime.today()
ticker = "NTDOY"
window = 21

# %%
rs_series = rolling_sharpe(start, end, ticker, window)
plot_rs(ticker, rs_series)

# %%
yf.Ticker('UBI')
# Out:
# yfinance.Ticker object <UBI>
